# %% [markdown]
# <a href="https://colab.research.google.com/github/dayanagg2025-create/Lenguajes-de-programci-n/blob/main/Taller_2_PORTAFOLIOS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #TALLER 2 ANÁLISIS DE PORTAFOLIOS

# %% [markdown]
# ## 1. Importación de librerias
# Primero importa las librerias necesarias (yfiance, pandas,numpu,matplotlib, dearborn)

# %%
#COMPLETAR: importar librerias necesarias (yfiance, pandas, numpy, matplotlibb, searbon)
#Ejemplo: import yfiance as yf

#COMPLETAR aquí

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %pip install yfinance

# %% [markdown]
# ## 2. Descarga los datos
# unsa "yfinance" para descargar los precios de **GOOGLE (GOOG)**,**Amazon (AMZN)** Y MIcrosoft (MSFT)** durante los ultimos tres años.
# Utiliza la columna "Adj Close"
# - Pregunta: ¿ Por qué es más adecuado usar Adj Close que Close para un análisis financiero?
#
#
# Adj Close = No existe la columna ( NO DISPONIBLE), debido que no está indicadp en el ticket por lo tanto nos aparece un ERROR al no estar disponible
#
# Close = Precios. Muestra los datos completos del precio de cierre.

# %%
#Completar: descarga los precios de las acciones yf.download

acciones = ["MSFT", "GOOG", "AMZN"]
data = yf.download(tickers=acciones)["Close"]
data.head() #veo los primeros 5 datos
# Out:
# /tmp/ipython-input-3244640554.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers=acciones)["Close"]
# [*********************100%***********************]  3 of 3 completed
# Ticker            AMZN        GOOG        MSFT
# Date
# 2025-08-19  228.009995  202.309189  508.933350
# 2025-08-20  223.809998  200.011230  504.890015
# 2025-08-21  221.949997  200.440842  504.239990
# 2025-08-22  228.839996  206.535400  507.230011
# 2025-08-25  227.940002  208.973221  504.260010

# %%
data.tail() #veo ultimos 5 años
# Out:
# Ticker            AMZN        GOOG        MSFT
# Date
# 2025-09-12  228.149994  241.380005  509.899994
# 2025-09-15  231.429993  251.759995  515.359985
# 2025-09-16  234.050003  251.419998  509.040009
# 2025-09-17  231.619995  249.850006  510.019989
# 2025-09-18  231.229996  252.330002  508.450012
